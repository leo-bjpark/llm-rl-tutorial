# %%
from src_ppo import run_ppo_training

model_name = "google/gemma-3-4b-it"
sft_lora_path = f"checkpoints/{model_name}-sft-lora"
reward_model_path = f"checkpoints/{model_name}-rm-lora"
output_dir = f"checkpoints/{model_name}-ppo-lora"

run_ppo_training(
    model_name=model_name,
    reward_model_path=reward_model_path,
    sft_lora_path=sft_lora_path,
    output_dir=output_dir,
    split="train",
    max_samples=100,
    batch_size=1,
    lr=1e-5,
    kl_coef=0.1,
    clip_epsilon=0.2,
    max_new_tokens=128,
    max_length=512,
    steps=50,
    ppo_epochs=4,
    temperature=0.7,
    top_p=0.9,
)
# Out:
# /home/bumjin/anaconda3/lib/python3.11/site-packages/transformers/utils/hub.py:110: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# 2026-01-16 10:01:09.988214: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-16 10:01:10.001926: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-16 10:01:10.015948: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
